# %% [markdown]
# ```python
# import yfinance as yf
#
# # Fetch historical data for the S&P 500 index
# sp500 = yf.Ticker("^GSPC")
# data = sp500.history(period="max")
# #data.to_csv("sp500_data.csv")
#
# nasdaq = yf.Ticker("^NDX")
# nasdaq_data = nasdaq.history(period="max")
# nasdaq_data.to_csv("nasdaq100_data.csv")
#
# dowjones = yf.Ticker("^DJI")
# dowjones_data = dowjones.history(period="max")
# dowjones_data.to_csv("dowjones_data.csv")
# ```

# %%
def set_seed(seed=42):
    import torch
    import random
    import numpy as np

    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)

# %%
import pandas as pd

data_name = "sp500"

# Load the data from the CSV file
data = pd.read_csv("sp500_data.csv", index_col='Date', parse_dates=True)
data.index = pd.to_datetime(data.index, utc=True)  # Ensure timezone-aware objects are converted to UTC
data.index = data.index.tz_convert(None)  # Remove timezone information
# Verify the loaded data
#print(data.head())

data['Return'] = data['Close'].pct_change()
data['Return_Squared'] = data['Return'] ** 2
data['Positive_Return'] = (data['Return'] > 0).astype(int)
data['Return_Squared_Positive'] = data['Return_Squared'] * data['Positive_Return']

start_date = pd.Timestamp("2000-02-29")
end_date = pd.Timestamp("2020-02-28")
filtered_data = data.loc[start_date:end_date]
filtered_data.drop(columns=['Dividends', 'Stock Splits'], inplace=True)
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_16692\886797826.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data.drop(columns=['Dividends', 'Stock Splits'], inplace=True)

# %%
df_normalized = filtered_data.copy()
columns_to_normalize = filtered_data.columns

for column in columns_to_normalize:
    col_mean = filtered_data[column].mean()
    col_min = filtered_data[column].min()
    col_max = filtered_data[column].max()

    df_normalized[column] = (filtered_data[column] - col_mean) / (col_max - col_min)

# %%
import numpy as np

# Use all features, including 'Return_Squared'
features = df_normalized.columns
target = 'Return'

# Create input (x) and label (y)
sequence_length = 20  # Number of days in the input window
X, y = [], []

# Iterate over the data to create sequences
for i in range(len(df_normalized) - sequence_length):
    # Get the input window of 20 rows
    X.append(df_normalized[features].iloc[i:i + sequence_length].values)
    # Get the target (current r^2)
    y.append(filtered_data[target].iloc[i + sequence_length])

# Convert to numpy arrays for model compatibility
X = np.array(X)
y = np.array(y)

print("Shape of X:", X.shape)  # Should be (num_samples, 20, n_columns)
print("Shape of y:", y.shape)  # Should be (num_samples,)
# Out:
# Shape of X: (5011, 20, 9)
# Shape of y: (5011,)

# %%
from sklearn.model_selection import train_test_split

# Determine split index
#train_size = int(0.9 * len(X))
train_size = int(0.8 * len(X))
val_size = int(0.1 * len(X))

# Split the data
#X_train, X_test = X[:train_size], X[train_size:]
#y_train, y_test = y[:train_size], y[train_size:]

X_train, X_val, X_test = X[:train_size], X[train_size:train_size+val_size], X[train_size+val_size:]
y_train, y_val, y_test = y[:train_size], y[train_size:train_size+val_size], y[train_size+val_size:]

print("Training set shape:", X_train.shape, y_train.shape)
print("Test set shape:", X_test.shape, y_test.shape)
print("Val set shape:", X_val.shape, y_val.shape)
# Out:
# Training set shape: (4008, 20, 9) (4008,)
# Test set shape: (502, 20, 9) (502,)
# Val set shape: (501, 20, 9) (501,)

# %%
import torch
from torch.utils.data import Dataset

class TimeSeriesDataset(Dataset):
    def __init__(self, inputs, targets):
        self.inputs = inputs
        self.targets = targets

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, idx):
        # Return input and target as tensors
        return torch.tensor(self.inputs[idx], dtype=torch.float32), torch.tensor(self.targets[idx], dtype=torch.float32)

# %%
batch_size = 500

# Create Dataset objects
train_dataset = TimeSeriesDataset(X_train, y_train)
test_dataset = TimeSeriesDataset(X_test, y_test)
val_dataset = TimeSeriesDataset(X_val, y_val)

from torch.utils.data import DataLoader

# Create DataLoader objects
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,generator=torch.Generator().manual_seed(42))  # Shuffle for training
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)  # No shuffle for testing
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False) 

print("Number of training batches:", len(train_loader))
print("Number of testing batches:", len(test_loader))
print("Number of val batches:", len(val_loader))
# Out:
# Number of training batches: 9
# Number of testing batches: 2
# Number of val batches: 2

# %%
import torch
import torch.nn as nn

class ANN(nn.Module):
    def __init__(self, input_size, lstm_hidden_size, dense_hidden_sizes):
        super(ANN, self).__init__()
        self.lstm = nn.LSTM(input_size, lstm_hidden_size, batch_first=True)
        
        # Define dense layers
        dense_layers = []
        prev_size = lstm_hidden_size  # Output size of LSTM
        for size in dense_hidden_sizes:
            dense_layers.append(nn.Linear(prev_size, size))
            # Using identity (no activation) based on the paper
            prev_size = size
        dense_layers.append(nn.Linear(prev_size, 1))
            
        self.dense = nn.Sequential(*dense_layers)

        # Final softplus layer for non-negative output
        self.softplus = nn.Softplus()

    def forward(self, x):
        # Pass through LSTM
        lstm_out, _ = self.lstm(x)
        last_hidden_state = lstm_out[:, -1, :]  # Take the last time step's output
        
        # Pass through dense layers
        dense_out = self.dense(last_hidden_state)
        
        # Apply softplus activation to ensure non-negative output
        output = self.softplus(dense_out)**2
        return output

# %%
class ANN_drop_act(nn.Module):
    def __init__(self, input_size, lstm_hidden_size, dense_hidden_sizes, dropout_rate=0.0, activation=None):
        """
        Args:
            input_size: Number of input features.
            lstm_hidden_size: Hidden size for LSTM.
            dense_hidden_sizes: List of hidden layer sizes for the dense block.
            dropout_rate: Dropout rate to apply after LSTM and dense layers.
            activation: Activation function (e.g., nn.ReLU, nn.Tanh).
        """
        super(ANN_drop_act,self).__init__()
        self.lstm = nn.LSTM(input_size, lstm_hidden_size, batch_first=True)
        self.dropout_lstm = nn.Dropout(dropout_rate)  # Dropout after LSTM

        # Define dense layers
        dense_layers = []
        prev_size = lstm_hidden_size
        for size in dense_hidden_sizes:
            dense_layers.append(nn.Linear(prev_size, size))
            if activation:
                dense_layers.append(activation())  # Activation function
            if dropout_rate > 0:
                dense_layers.append(nn.Dropout(dropout_rate))  # Dropout
            prev_size = size

        # Final layer to output 1 value
        dense_layers.append(nn.Linear(prev_size, 1))
        self.dense = nn.Sequential(*dense_layers)

        # Final softplus layer for non-negative output
        self.softplus = nn.Softplus()

    def forward(self, x):
        # Pass through LSTM
        lstm_out, _ = self.lstm(x)
        last_hidden_state = lstm_out[:, -1, :]  # Last time step output
        
        # Dropout after LSTM
        lstm_out = self.dropout_lstm(last_hidden_state)
        
        # Pass through dense layers
        dense_out = self.dense(lstm_out)
        
        # Apply softplus activation to ensure non-negative output
        output = self.softplus(dense_out) ** 2
        return output

# %%
class ANN_multiplier(nn.Module):
    def __init__(self, input_size, lstm_hidden_size, dense_hidden_sizes, dropout_rate=0.0, activation=None):
        """
        Args:
            input_size: Number of input features.
            lstm_hidden_size: Hidden size for LSTM.
            dense_hidden_sizes: List of hidden layer sizes for the dense block.
            dropout_rate: Dropout rate to apply after LSTM and dense layers.
            activation: Activation function (e.g., nn.ReLU, nn.Tanh).
        """
        super(ANN_drop_act,self).__init__()
        self.lstm = nn.LSTM(input_size, lstm_hidden_size, batch_first=True, num_layers=2, dropout=dropout_rate)
        self.dropout_lstm = nn.Dropout(dropout_rate)  # Dropout after LSTM

        # Define dense layers
        dense_layers = []
        prev_size = lstm_hidden_size
        for size in dense_hidden_sizes:
            dense_layers.append(nn.Linear(prev_size, size))
            if activation:
                dense_layers.append(activation())  # Activation function
            if dropout_rate > 0:
                dense_layers.append(nn.Dropout(dropout_rate))  # Dropout
            prev_size = size

        # Final layer to output 1 value
        dense_layers.append(nn.Linear(prev_size, 1))
        self.dense = nn.Sequential(*dense_layers)

        # Final softplus layer for non-negative output
        self.softplus = nn.Softplus()

    def forward(self, x):
        # Pass through LSTM
        lstm_out, _ = self.lstm(x)
        last_hidden_state = lstm_out[:, -1, :]  # Last time step output
        
        # Dropout after LSTM
        lstm_out = self.dropout_lstm(last_hidden_state)
        
        # Pass through dense layers
        dense_out = self.dense(lstm_out)
        
        # Apply softplus activation to ensure non-negative output
        output = self.softplus(dense_out) ** 2
        return output

# %%
class ANN_CNN_LSTM(nn.Module):
    def __init__(self, input_size, lstm_hidden_size, dense_hidden_sizes, dropout_rate=0.0, activation=None):
        super(ANN_CNN_LSTM, self).__init__()
        # 1D CNN
        self.conv1 = nn.Conv1d(in_channels=input_size, out_channels=16, kernel_size=3, padding=1)
        self.pool = nn.MaxPool1d(kernel_size=2)

        # LSTM
        self.lstm = nn.LSTM(16, lstm_hidden_size, batch_first=True)
        self.dropout_lstm = nn.Dropout(dropout_rate)

        # Dense layers
        dense_layers = []
        prev_size = lstm_hidden_size
        for size in dense_hidden_sizes:
            dense_layers.append(nn.Linear(prev_size, size))
            if activation:
                dense_layers.append(activation())
            if dropout_rate > 0:
                dense_layers.append(nn.Dropout(dropout_rate))
            prev_size = size
        dense_layers.append(nn.Linear(prev_size, 1))
        
        self.dense = nn.Sequential(*dense_layers)
        self.softplus = nn.Softplus()

    def forward(self, x):
        x = x.permute(0, 2, 1)  # Change to (batch, channels, time_steps) for CNN
        cnn_out = self.pool(torch.relu(self.conv1(x)))
        cnn_out = cnn_out.permute(0, 2, 1)  # Back to (batch, time_steps, channels)

        # LSTM
        lstm_out, _ = self.lstm(cnn_out)
        last_hidden_state = self.dropout_lstm(lstm_out[:, -1, :])

        # Dense layers
        dense_out = self.dense(last_hidden_state)
        output = self.softplus(dense_out) ** 2
        return output

# %%
class ANN_Attention(nn.Module):
    def __init__(self, input_size, lstm_hidden_size, dense_hidden_sizes, num_heads=1, dropout_rate=0.0, activation=None):
        super(ANN_Attention, self).__init__()
        self.lstm = nn.LSTM(input_size, lstm_hidden_size, batch_first=True)
        self.attention = nn.MultiheadAttention(embed_dim=lstm_hidden_size, num_heads=num_heads, dropout=dropout_rate, batch_first=True)
        
        dense_layers = []
        prev_size = lstm_hidden_size
        for size in dense_hidden_sizes:
            dense_layers.append(nn.Linear(prev_size, size))
            if activation:
                dense_layers.append(activation())  # Activation function
            if dropout_rate > 0:
                dense_layers.append(nn.Dropout(dropout_rate))  # Dropout
            prev_size = size
        dense_layers.append(nn.Linear(prev_size, 1))

        self.dense = nn.Sequential(*dense_layers)
        self.softplus = nn.Softplus()

    def forward(self, x):
        lstm_out, _ = self.lstm(x)  # Shape: (batch, time_steps, hidden_size)
        attn_output, _ = self.attention(lstm_out, lstm_out, lstm_out)  # Self-attention on LSTM outputs
        attn_output = attn_output[:, -1, :]  # Use the last time step after attention

        dense_out = self.dense(attn_output)
        output = self.softplus(dense_out) ** 2
        return output

# %%
import torch
import torch.nn as nn

class StudentTNegativeLogLikelihood(nn.Module):
    def __init__(self, nu):
        """
        Custom loss function for the Student's t-distribution negative log-likelihood.
        
        Parameters:
            nu (float): Degrees of freedom (must be > 2).
        """
        super(StudentTNegativeLogLikelihood, self).__init__()
        self.nu = nu  # Degrees of freedom (constant for now)
        assert nu > 2, "Degrees of freedom (nu) must be greater than 2."

    def forward(self, r_t, h_t):
        """
        Compute the negative log-likelihood loss.

        Parameters:
            r_t (Tensor): Target returns (batch_size,).
            h_t (Tensor): Predicted conditional variances (batch_size,).

        Returns:
            Tensor: Negative log-likelihood loss.
        """
        # Precompute constants
        log_gamma_nu_plus_1_2 = torch.lgamma(torch.tensor((self.nu + 1) / 2))
        log_gamma_nu_2 = torch.lgamma(torch.tensor(self.nu / 2))
        log_pi = torch.log(torch.tensor(torch.pi))
        log_nu_minus_2 = torch.log(torch.tensor(self.nu - 2))

        # Compute each term
        term1 = log_gamma_nu_plus_1_2 - log_gamma_nu_2
        term2 = -0.5 * (log_pi + log_nu_minus_2 + torch.log(h_t))
        term3 = -((self.nu + 1) / 2) * torch.log(1 + (r_t**2) / ((self.nu - 2) * h_t))

        # Combine terms
        log_likelihood = term1 + term2 + term3
        negative_log_likelihood = -torch.sum(log_likelihood)

        return negative_log_likelihood

# %%
import torch.optim as optim
# Training and Validation
def train_and_validate(model, train_loader, test_loader, criterion, optimizer, epochs, patience=10):
    train_losses, test_losses = [], []
    best_loss = float('inf')
    patience_counter = 0


    for epoch in range(epochs):
        model.train()
        train_loss = 0
        for inputs, targets in train_loader:
            optimizer.zero_grad()
            predictions = model(inputs).squeeze()  # Predicted variances
            #print(predictions.shape, targets.shape)
            loss = criterion(targets, predictions)  # Negative log-likelihood
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        # Validation on test data
        model.eval()
        test_loss = 0
        with torch.no_grad():
            for inputs, targets in test_loader:
                predictions = model(inputs).squeeze()
                loss = criterion(targets, predictions)
                test_loss += loss.item()

        # Record average losses
        train_losses.append(train_loss / len(train_loader))
        test_losses.append(test_loss / len(test_loader))

        print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_losses[-1]:.4f}, Test Loss: {test_losses[-1]:.4f}")
        
        # Early Stopping Check
        if test_losses[-1] < best_loss:
            best_loss = test_losses[-1]
            patience_counter = 0  # Reset patience counter
            torch.save(model.state_dict(), "best_model.pth")  # Save the best model
        else:
            patience_counter += 1
            print(f"EarlyStopping counter: {patience_counter} out of {patience}")
        
        if patience_counter >= patience:
            print("Early stopping triggered!")
            break
            
    model.load_state_dict(torch.load("best_model.pth"))

    return model, train_losses, test_losses

# %%
input_size = X_train.shape[2]
# Run predictions and calculate MSE for both models
models = {
    "Model 1, LSTM(32) + Dense(16-8)": ANN(input_size=input_size, lstm_hidden_size=32, dense_hidden_sizes=[16, 8]), 
    "Model 2, LSTM(32) + Dense(32-16-8)": ANN(input_size=input_size, lstm_hidden_size=32, dense_hidden_sizes=[32, 16, 8]), 
    "Model 3, LSTM(32) + Dense(64-32-16-8)": ANN(input_size=input_size, lstm_hidden_size=32, dense_hidden_sizes=[64,32, 16, 8]), 
    "Model 4, LSTM(32) + Dense(64-32-16-8) + dropout0.1": ANN_drop_act(input_size=input_size, lstm_hidden_size=32, dense_hidden_sizes=[64, 32, 16, 8], dropout_rate=0.1, activation=None), 
    "Model 5, LSTM(32) + Dense(64-32-16-8) + dropout0.2": ANN_drop_act(input_size=input_size, lstm_hidden_size=32, dense_hidden_sizes=[64,32, 16, 8], dropout_rate=0.2, activation=None),
    "Model 6, LSTM(32) + Dense(64-32-16-8) + dropout0.3": ANN_drop_act(input_size=input_size, lstm_hidden_size=32, dense_hidden_sizes=[64,32, 16, 8], dropout_rate=0.3, activation=None),
    #"Model 7, LSTM(32) + Dense(128-64-32-16-8) + dropout0.1": ANN_drop_act(input_size=input_size, lstm_hidden_size=32, dense_hidden_sizes=[128, 64, 32, 16, 8], dropout_rate=0.1, activation=None), 
    #"Model 7, LSTM(32) + Dense(64-32-16-8) + dropout0.1 + 2 layer LSTM": ANN_drop_act(input_size=input_size, lstm_hidden_size=32, dense_hidden_sizes=[64,32, 16, 8], dropout_rate=0.1, activation=None),
    #"Model 8, LSTM(32) + Dense(64-32-16-8) + dropout0.1 + CNN": ANN_CNN_LSTM(input_size=input_size, lstm_hidden_size=32, dense_hidden_sizes=[64,32, 16, 8], dropout_rate=0.1),
    #"Model 9, LSTM(32) + Dense(64-32-16-8) + dropout0.1 + Atten": ANN_Attention(input_size=input_size, lstm_hidden_size=32, dense_hidden_sizes=[64,32, 16, 8], dropout_rate=0.1),
         }

# %%
import matplotlib.pyplot as plt


nu = 6.0  # Degrees of freedom
epochs = 500

# Define loss function
criterion = StudentTNegativeLogLikelihood(nu)

plt.figure(figsize=(10, 6))

for name, model in models.items():
    optimizer = optim.Adam(model.parameters(), lr=0.0001)
    print(f"Training {name}")
    trained_model, train_losses, test_losses = train_and_validate(model, train_loader, val_loader, criterion, optimizer, epochs)
    models[name] = trained_model
    
    #plt.plot(train_losses, label=f"Train Loss {name}")
    plt.plot(test_losses, label=f"Test Loss {name}")
    
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training and Test Loss Comparison")
plt.legend()
plt.show()
# Out:
# Training Model 1, LSTM(32) + Dense(16-8)
# Epoch 1/500, Train Loss: 133.1165, Test Loss: 76.4352
# Epoch 2/500, Train Loss: 130.2564, Test Loss: 74.9397
# Epoch 3/500, Train Loss: 127.4962, Test Loss: 73.4618
# Epoch 4/500, Train Loss: 124.7651, Test Loss: 71.9911
# Epoch 5/500, Train Loss: 122.0411, Test Loss: 70.5230
# Epoch 6/500, Train Loss: 119.3094, Test Loss: 69.0508
# Epoch 7/500, Train Loss: 116.5528, Test Loss: 67.5677
# Epoch 8/500, Train Loss: 113.7555, Test Loss: 66.0689
# Epoch 9/500, Train Loss: 110.8994, Test Loss: 64.5463
# Epoch 78/500, Train Loss: -1237.6893, Test Loss: -871.9165
# EarlyStopping counter: 1 out of 10
# Epoch 79/500, Train Loss: -1227.9723, Test Loss: -874.3222
# Epoch 80/500, Train Loss: -1230.2150, Test Loss: -878.9817
# Epoch 81/500, Train Loss: -1238.3034, Test Loss: -884.9228
# Epoch 82/500, Train Loss: -1238.2458, Test Loss: -886.5318
# Epoch 83/500, Train Loss: -1238.0810, Test Loss: -896.9945
# Epoch 84/500, Train Loss: -1236.4214, Test Loss: -893.9863
# EarlyStopping counter: 1 out of 10
# Epoch 85/500, Train Loss: -1247.0435, Test Loss: -900.7988
# Epoch 86/500, Train Loss: -1242.3216, Test Loss: -897.2836
# EarlyStopping counter: 1 out of 10
# Epoch 87/500, Train Loss: -1252.1290, Test Loss: -897.6081
# EarlyStopping counter: 2 out of 10
# Epoch 88/500, Train Loss: -1246.5511, Test Loss: -904.3205
# Epoch 89/500, Train Loss: -1248.9795, Test Loss: -906.9766
# Epoch 90/500, Train Loss: -1245.2486, Test Loss: -899.1058
# EarlyStopping counter: 1 out of 10
# Epoch 91/500, Train Loss: -1249.2376, Test Loss: -907.0830
# Epoch 92/500, Train Loss: -1240.7811, Test Loss: -904.1260
# EarlyStopping counter: 1 out of 10
# Epoch 93/500, Train Loss: -1235.2374, Test Loss: -904.4048
# EarlyStopping counter: 2 out of 10
# Epoch 94/500, Train Loss: -1250.2815, Test Loss: -905.1884
# EarlyStopping counter: 3 out of 10
# Epoch 95/500, Train Loss: -1256.6297, Test Loss: -908.0369
# Epoch 96/500, Train Loss: -1249.5357, Test Loss: -911.5354
# Epoch 97/500, Train Loss: -1254.1222, Test Loss: -899.9215
# EarlyStopping counter: 1 out of 10
# Epoch 98/500, Train Loss: -1253.2862, Test Loss: -914.1789
# Epoch 99/500, Train Loss: -1254.7183, Test Loss: -902.4681
# EarlyStopping counter: 1 out of 10
# Epoch 100/500, Train Loss: -1249.3702, Test Loss: -905.9333
# EarlyStopping counter: 2 out of 10
# Epoch 101/500, Train Loss: -1257.6927, Test Loss: -915.6456
# Epoch 102/500, Train Loss: -1254.0656, Test Loss: -904.6819
# EarlyStopping counter: 1 out of 10
# Epoch 103/500, Train Loss: -1259.2490, Test Loss: -917.3124
# Epoch 104/500, Train Loss: -1254.1269, Test Loss: -913.7494
# EarlyStopping counter: 1 out of 10
# Epoch 105/500, Train Loss: -1249.2898, Test Loss: -910.7290
# EarlyStopping counter: 2 out of 10
# Epoch 106/500, Train Loss: -1259.3118, Test Loss: -914.9605
# EarlyStopping counter: 3 out of 10
# Epoch 107/500, Train Loss: -1259.1305, Test Loss: -912.1607
# EarlyStopping counter: 4 out of 10
# Epoch 108/500, Train Loss: -1257.8865, Test Loss: -909.7907
# EarlyStopping counter: 5 out of 10
# Epoch 109/500, Train Loss: -1250.4004, Test Loss: -908.0090
# EarlyStopping counter: 6 out of 10
# Epoch 110/500, Train Loss: -1268.1507, Test Loss: -913.6660
# EarlyStopping counter: 7 out of 10
# Epoch 111/500, Train Loss: -1255.7118, Test Loss: -909.5677
# EarlyStopping counter: 8 out of 10
# Epoch 112/500, Train Loss: -1260.4346, Test Loss: -915.2338
# EarlyStopping counter: 9 out of 10
# Epoch 113/500, Train Loss: -1265.7408, Test Loss: -918.3572
# Epoch 114/500, Train Loss: -1254.8554, Test Loss: -908.3706
# EarlyStopping counter: 1 out of 10
# Epoch 115/500, Train Loss: -1262.3142, Test Loss: -910.3052
# EarlyStopping counter: 2 out of 10
# Epoch 116/500, Train Loss: -1267.4361, Test Loss: -912.5122
# EarlyStopping counter: 3 out of 10
# Epoch 117/500, Train Loss: -1268.3177, Test Loss: -910.5777
# EarlyStopping counter: 4 out of 10
# Epoch 118/500, Train Loss: -1266.7395, Test Loss: -916.5512
# EarlyStopping counter: 5 out of 10
# Epoch 119/500, Train Loss: -1268.5811, Test Loss: -914.9896
# EarlyStopping counter: 6 out of 10
# Epoch 120/500, Train Loss: -1267.0502, Test Loss: -911.2385
# EarlyStopping counter: 7 out of 10
# Epoch 121/500, Train Loss: -1264.4815, Test Loss: -911.0382
# EarlyStopping counter: 8 out of 10
# Epoch 122/500, Train Loss: -1267.5598, Test Loss: -913.9912
# EarlyStopping counter: 9 out of 10
# Epoch 123/500, Train Loss: -1265.6882, Test Loss: -918.6421
# Epoch 124/500, Train Loss: -1270.8122, Test Loss: -899.2232
# EarlyStopping counter: 1 out of 10
# Epoch 125/500, Train Loss: -1281.7924, Test Loss: -920.8067
# Epoch 126/500, Train Loss: -1263.2179, Test Loss: -911.3532
# EarlyStopping counter: 1 out of 10
# Epoch 127/500, Train Loss: -1271.3553, Test Loss: -914.9209
# EarlyStopping counter: 2 out of 10
# Epoch 128/500, Train Loss: -1277.4149, Test Loss: -924.9947
# Epoch 129/500, Train Loss: -1255.2656, Test Loss: -900.1849
# EarlyStopping counter: 1 out of 10
# Epoch 130/500, Train Loss: -1264.2505, Test Loss: -920.2514
# EarlyStopping counter: 2 out of 10
# Epoch 131/500, Train Loss: -1277.1556, Test Loss: -917.8892
# EarlyStopping counter: 3 out of 10
# Epoch 132/500, Train Loss: -1273.2379, Test Loss: -915.8198
# EarlyStopping counter: 4 out of 10
# Epoch 133/500, Train Loss: -1275.8087, Test Loss: -917.3775
# EarlyStopping counter: 5 out of 10
# Epoch 134/500, Train Loss: -1272.6014, Test Loss: -910.2455
# EarlyStopping counter: 6 out of 10
# Epoch 135/500, Train Loss: -1273.7484, Test Loss: -914.6680
# EarlyStopping counter: 7 out of 10
# Epoch 136/500, Train Loss: -1266.2526, Test Loss: -916.4066
# EarlyStopping counter: 8 out of 10
# Epoch 137/500, Train Loss: -1266.1132, Test Loss: -911.4922
# EarlyStopping counter: 9 out of 10
# Epoch 138/500, Train Loss: -1277.4662, Test Loss: -919.3357
# EarlyStopping counter: 10 out of 10
# Early stopping triggered!
# Training Model 5, LSTM(32) + Dense(64-32-16-8) + dropout0.
# Epoch 46/500, Train Loss: -893.4514, Test Loss: -594.3681
# Epoch 47/500, Train Loss: -888.6255, Test Loss: -573.9823
# EarlyStopping counter: 1 out of 10
# Epoch 48/500, Train Loss: -908.3624, Test Loss: -582.0181
# EarlyStopping counter: 2 out of 10
# Epoch 49/500, Train Loss: -899.0978, Test Loss: -603.9988
# Epoch 50/500, Train Loss: -896.4620, Test Loss: -603.9337
# EarlyStopping counter: 1 out of 10
# Epoch 51/500, Train Loss: -888.0293, Test Loss: -606.3289
# Epoch 52/500, Train Loss: -912.2588, Test Loss: -617.5138
# Epoch 53/500, Train Loss: -930.7973, Test Loss: -641.9635
# Epoch 54/500, Train Loss: -910.0174, Test Loss: -652.3230
# Epoch 55/500, Train Loss: -911.5877, Test Loss: -641.7961
# EarlyStopping counter: 1 out of 10
# Epoch 56/500, Train Loss: -916.9220, Test Loss: -649.3839
# EarlyStopping counter: 2 out of 10
# Epoch 57/500, Train Loss: -918.3234, Test Loss: -658.9611
# Epoch 58/500, Train Loss: -904.9400, Test Loss: -651.0531
# EarlyStopping counter: 1 out of 10
# Epoch 59/500, Train Loss: -918.7091, Test Loss: -661.0496
# Epoch 60/500, Train Loss: -923.4888, Test Loss: -688.7160
# Epoch 61/500, Train Loss: -910.2565, Test Loss: -682.7354
# EarlyStopping counter: 1 out of 10
# Epoch 62/500, Train Loss: -918.7777, Test Loss: -670.1883
# EarlyStopping counter: 2 out of 10
# Epoch 63/500, Train Loss: -931.3767, Test Loss: -700.5256
# Epoch 64/500, Train Loss: -934.8144, Test Loss: -710.9424
# Epoch 65/500, Train Loss: -928.7817, Test Loss: -698.3178
# EarlyStopping counter: 1 out of 10
# Epoch 66/500, Train Loss: -922.5194, Test Loss: -696.0560
# EarlyStopping counter: 2 out of 10
# Epoch 67/500, Train Loss: -933.4983, Test Loss: -708.7070
# EarlyStopping counter: 3 out of 10
# Epoch 68/500, Train Loss: -921.6714, Test Loss: -706.9189
# EarlyStopping counter: 4 out of 10
# Epoch 69/500, Train Loss: -945.4106, Test Loss: -728.7912
# Epoch 70/500, Train Loss: -931.8700, Test Loss: -724.0041
# EarlyStopping counter: 1 out of 10
# Epoch 71/500, Train Loss: -942.9085, Test Loss: -717.5510
# EarlyStopping counter: 2 out of 10
# Epoch 72/500, Train Loss: -947.4332, Test Loss: -733.7966
# Epoch 73/500, Train Loss: -927.2614, Test Loss: -724.9710
# EarlyStopping counter: 1 out of 10
# Epoch 74/500, Train Loss: -934.5079, Test Loss: -723.0875
# EarlyStopping counter: 2 out of 10
# Epoch 75/500, Train Loss: -927.3644, Test Loss: -716.8733
# EarlyStopping counter: 3 out of 10
# Epoch 76/500, Train Loss: -941.6502, Test Loss: -747.3193
# Epoch 77/500, Train Loss: -940.8369, Test Loss: -733.6084
# EarlyStopping counter: 1 out of 10
# Epoch 78/500, Train Loss: -960.1659, Test Loss: -738.7225
# EarlyStopping counter: 2 out of 10
# Epoch 79/500, Train Loss: -947.9270, Test Loss: -747.9441
# Epoch 80/500, Train Loss: -957.7615, Test Loss: -738.6027
# EarlyStopping counter: 1 out of 10
# Epoch 81/500, Train Loss: -962.2010, Test Loss: -750.1124
# Epoch 82/500, Train Loss: -946.9843, Test Loss: -754.3577
# Epoch 83/500, Train Loss: -956.9694, Test Loss: -743.3445
# EarlyStopping counter: 1 out of 10
# Epoch 84/500, Train Loss: -948.2526, Test Loss: -746.8625
# EarlyStopping counter: 2 out of 10
# Epoch 85/500, Train Loss: -956.7781, Test Loss: -748.1446
# EarlyStopping counter: 3 out of 10
# Epoch 86/500, Train Loss: -966.9812, Test Loss: -762.9068
# Epoch 87/500, Train Loss: -954.3963, Test Loss: -757.6910
# EarlyStopping counter: 1 out of 10
# Epoch 88/500, Train Loss: -956.8187, Test Loss: -747.8145
# EarlyStopping counter: 2 out of 10
# Epoch 89/500, Train Loss: -971.6763, Test Loss: -759.5791
# EarlyStopping counter: 3 out of 10
# Epoch 90/500, Train Loss: -966.4344, Test Loss: -752.9200
# EarlyStopping counter: 4 out of 10
# Epoch 91/500, Train Loss: -963.2955, Test Loss: -771.3886
# Epoch 92/500, Train Loss: -969.8180, Test Loss: -772.0138
# Epoch 93/500, Train Loss: -962.8078, Test Loss: -760.0914
# EarlyStopping counter: 1 out of 10
# Epoch 94/500, Train Loss: -947.4494, Test Loss: -748.2697
# EarlyStopping counter: 2 out of 10
# Epoch 95/500, Train Loss: -965.6042, Test Loss: -768.3956
# EarlyStopping counter: 3 out of 10
# Epoch 96/500, Train Loss: -957.4199, Test Loss: -771.8001
# EarlyStopping counter: 4 out of 10
# Epoch 97/500, Train Loss: -961.4052, Test Loss: -758.9552
# EarlyStopping counter: 5 out of 10
# Epoch 98/500, Train Loss: -979.1115, Test Loss: -776.0454
# Epoch 99/500, Train Loss: -968.4759, Test Loss: -782.6200
# Epoch 100/500, Train Loss: -968.3563, Test Loss: -771.2469
# EarlyStopping counter: 1 out of 10
# Epoch 101/500, Train Loss: -959.7420, Test Loss: -758.6918
# EarlyStopping counter: 2 out of 10
# Epoch 102/500, Train Loss: -987.5044, Test Loss: -772.4664
# EarlyStopping counter: 3 out of 10
# Epoch 103/500, Train Loss: -968.0288, Test Loss: -771.5317
# EarlyStopping counter: 4 out of 10
# Epoch 104/500, Train Loss: -975.3456, Test Loss: -771.8845
# EarlyStopping counter: 5 out of 10
# Epoch 105/500, Train Loss: -982.2030, Test Loss: -773.5092
# EarlyStopping counter: 6 out of 10
# Epoch 106/500, Train Loss: -977.0891, Test Loss: -769.6344
# EarlyStopping counter: 7 out of 10
# Epoch 107/500, Train Loss: -973.5993, Test Loss: -760.1922
# EarlyStopping counter: 8 out of 10
# Epoch 108/500, Train Loss: -982.4266, Test Loss: -780.0591
# EarlyStopping counter: 9 out of 10
# Epoch 109/500, Train Loss: -989.8290, Test Loss: -792.2639
# Epoch 110/500, Train Loss: -966.8822, Test Loss: -765.5494
# EarlyStopping counter: 1 out of 10
# Epoch 111/500, Train Loss: -976.0149, Test Loss: -759.1467
# EarlyStopping counter: 2 out of 10
# Epoch 112/500, Train Loss: -999.1821, Test Loss: -780.3027
# EarlyStopping counter: 3 out of 10
# Epoch 113/500, Train Loss: -968.2469, Test Loss: -762.8742
# EarlyStopping counter: 4 out of 10
# Epoch 114/500, Train Loss: -990.4854, Test Loss: -768.9062
# EarlyStopping counter: 5 out of 10
# Epoch 115/500, Train Loss: -995.7339, Test Loss: -779.1438
# EarlyStopping counter: 6 out of 10
# Epoch 116/500, Train Loss: -989.7285, Test Loss: -788.9196
# EarlyStopping counter: 7 out of 10
# Epoch 117/500, Train Loss: -992.7884, Test Loss: -781.3100
# EarlyStopping counter: 8 out of 10
# Epoch 118/500, Train Loss: -986.4322, Test Loss: -769.6732
# EarlyStopping counter: 9 out of 10
# Epoch 119/500, Train Loss: -1006.3949, Test Loss: -784.6606
# EarlyStopping counter: 10 out of 10
# Early stopping triggered!

# %%
import scipy.special as sp
import matplotlib.pyplot as plt

# Function to compute E(|r_t|^c | S_{t-1})
def compute_expectation(h_t, c, nu):
    gamma_v_c = sp.gamma((nu - c) / 2)
    gamma_c_1 = sp.gamma((c + 1) / 2)
    gamma_v = sp.gamma(nu / 2)
    
    factor = (nu - 2) ** (c / 2) * (gamma_v_c * gamma_c_1) / (gamma_v * (np.pi ** 0.5))
    return (h_t ** (c / 2)) * factor

# Function to calculate MSE
def calculate_mse(r_t, expectations, c_values):
    mse_results = {}
    for c in c_values:
        true_values = np.abs(r_t) ** c
        mse = np.mean((true_values - expectations[c]) ** 2)
        mse_results[c] = mse
    return mse_results

def calculate_mae(r_t, expectations, c_values):
    mse_results = {}
    for c in c_values:
        true_values = np.abs(r_t) ** c
        mse = np.mean(np.abs((true_values - expectations[c])))
        mse_results[c] = mse
    return mse_results

# Predict variance h_t using a given model
def predict_variance(model, loader):
    model.eval()
    predicted_h = []

    with torch.no_grad():
        for inputs, _ in loader:
            h_t = model(inputs).squeeze()
            predicted_h.append(h_t)
    
    return torch.cat(predicted_h).cpu().numpy()

# %%
# Test data squared returns (labels)
r_squared = y_test ** 2  # True squared returns
#print(f"r_squared {r_squared[:5]}")

# c values for MSE calculation
c_values = [1, 1.5, 2]

# Degrees of freedom (nu)
nu = 6.0

mse_results_all = {}
mae_results_all = {}

# Number of models and grid configuration
num_models = len(models)
cols = 3  # Number of columns
rows = (num_models + cols - 1) // cols  # Calculate rows needed

# Create a figure with subplots
fig, axes = plt.subplots(rows, cols, figsize=(15, 5 * rows))
axes = axes.flatten()  # Flatten the axes array for easy indexing

for idx, (name, model) in enumerate(models.items()):
    print(f"Processing {name}...")
    
    # Step 1: Predict variance h_t
    predicted_h = predict_variance(model, test_loader)
    
    #print(f"predicted_h {predicted_h[:5]}")
    
    # Step 2: Compute E(|r_t|^c | S_{t-1}) for c = 1, 1.5, 2
    expectations = {c: compute_expectation(predicted_h, c, nu) for c in c_values}
    #print(f"expectations {expectations}")
    #for k in expectations:
        #print(k,expectations[k][:10])
        #print((np.sqrt(r_squared)**k)[:10])
    
    # Step 3: Calculate MSE
    mse_results = calculate_mse(np.sqrt(r_squared), expectations, c_values)
    mae_results = calculate_mae(np.sqrt(r_squared), expectations, c_values)
    mse_results_all[name] = mse_results
    mae_results_all[name] = mae_results
    
    # Step 4: Plot predicted variance vs. true r_t^2
    ax = axes[idx]  # Select subplot axis
    ax.plot(predicted_h, label="Predicted Variance (h_t)", alpha=0.7)
    ax.plot(r_squared, label="True Squared Returns (r_t^2)", alpha=0.7)
    ax.set_title(f"{name}")
    ax.set_xlabel("Time Steps")
    ax.set_ylabel("Variance")
    ax.legend()
    
# Remove unused subplots (if any)
for idx in range(len(models), len(axes)):
    fig.delaxes(axes[idx])

# Adjust layout
plt.tight_layout()
plt.savefig(f"{data_name}_ANN_variance_comparison.png", dpi=300, bbox_inches='tight')
plt.show()

# Print MSE results
print("\nMSE Comparison:")
for name, mse in mse_results_all.items():
    print(f"\n{name}:")
    for c, value in mse.items():
        print(f"  MSE for c = {c}: {value}")
        
# Print MSE results
print("\nMAE Comparison:")
for name, mse in mae_results_all.items():
    print(f"\n{name}:")
    for c, value in mse.items():
        print(f"  MAE for c = {c}: {value}")
# Out:
# Processing Model 1, LSTM(32) + Dense(16-8)...
# Processing Model 2, LSTM(32) + Dense(32-16-8)...
# Processing Model 3, LSTM(32) + Dense(64-32-16-8)...
# Processing Model 4, LSTM(32) + Dense(64-32-16-8) + dropout0.1...
# Processing Model 5, LSTM(32) + Dense(64-32-16-8) + dropout0.2...
# Processing Model 6, LSTM(32) + Dense(64-32-16-8) + dropout0.3...
# MSE Comparison:
#
# Model 1, LSTM(32) + Dense(16-8):
#   MSE for c = 1: 8.225110316276607e-05
#   MSE for c = 1.5: 2.7436644065305513e-06
#   MSE for c = 2: 1.0491103655693782e-07
#
# Model 2, LSTM(32) + Dense(32-16-8):
#   MSE for c = 1: 4.49436456603033e-05
#   MSE for c = 1.5: 1.3529296637433658e-06
#   MSE for c = 2: 4.473731787112727e-08
#
# Model 3, LSTM(32) + Dense(64-32-16-8):
#   MSE for c = 1: 4.7117621150157185e-05
#   MSE for c = 1.5: 1.399662623561573e-06
#   MSE for c = 2: 4.574663027044428e-08
#
# Model 4, LSTM(32) + Dense(64-32-16-8) + dropout0.1:
#   MSE for c = 1: 3.8596292338484144e-05
#   MSE for c = 1.5: 1.172912444207821e-06
#   MSE for c = 2: 3.94130613556207e-08
#
# Model 5, LSTM(32) + Dense(64-32-16-8) + dropout0.2:
#   MSE for c = 1: 4.12618962047382e-05
#   MSE for c = 1.5: 1.2027463425246987e-06
#   MSE for c = 2: 3.932567935628471e-08
#
# Model 6, LSTM(32) + Dense(64-32-16-8) + dropout0.3:
#   MSE for c = 1: 7.018135026323573e-05
#   MSE for c = 1.5: 2.226707421767533e-06
#   MSE for c = 2: 7.934297724988287e-08
#
# MAE Comparison:
#
# Model 1, LSTM(32) + Dense(16-8):
#   MAE for c = 1: 0.007709614145770144
#   MAE for c = 1.5: 0.0013370961972112478
#   MAE for c = 2: 0.0002388191197058458
#
# Model 2, LSTM(32) + Dense(32-16-8):
#   MAE for c = 1: 0.004268468434778336
#   MAE for c = 1.5: 0.0005771491130076452
#   MAE for c = 2: 8.067431652302954e-05
#
# Model 3, LSTM(32) + Dense(64-32-16-8):
#   MAE for c = 1: 0.004310282353737602
#   MAE for c = 1.5: 0.0005747670715211346
#   MAE for c = 2: 7.939180104408883e-05
#
# Model 4, LSTM(32) + Dense(64-32-16-8) + dropout0.1:
#   MAE for c = 1: 0.0041482704687917085
#   MAE for c = 1.5: 0.0005722744957467537
#   MAE for c = 2: 8.246246123408356e-05
#
# Model 5, LSTM(32) + Dense(64-32-16-8) + dropout0.2:
#   MAE for c = 1: 0.005062686193895597
#   MAE for c = 1.5: 0.0007783152704977777
#   MAE for c = 2: 0.00012371123978245822
#
# Model 6, LSTM(32) + Dense(64-32-16-8) + dropout0.3:
#   MAE for c = 1: 0.007328071704029257
#   MAE for c = 1.5: 0.0012990920743793928
#   MAE for c = 2: 0.0002367827030520405

# %%
import numpy as np
import pandas as pd
from arch import arch_model
import matplotlib.pyplot as plt

# Step 1: Train-Test Split
train_returns = y_train  # Training data
test_returns = y_test    # Test data
val_returns = y_val

# Initialize with training data
rolling_train_returns = np.append(train_returns,val_returns).copy()
rolling_train_returns *= 100
predicted_variance = []

for t in range(len(test_returns)):
    # Step 1: Fit GARCH-t(1,1) model to the rolling training data
    garch_t_model = arch_model(rolling_train_returns, vol="Garch", p=1, q=1, dist="t")
    res = garch_t_model.fit(disp="off")
    
    # Step 2: Forecast the next variance (h_t)
    forecast = res.forecast(start=len(rolling_train_returns)-1, horizon=1, reindex=False)
    h_t = forecast.variance.values[-1, 0]  # Forecasted variance
    
    # Step 3: Append the forecasted variance
    predicted_variance.append(h_t/100**2)
    
    # Step 4: Add the current test return to the rolling training set
    rolling_train_returns = np.append(rolling_train_returns, test_returns[t]*100)

# Convert to NumPy array
predicted_variance = np.array(predicted_variance)
garch_predicted_variance = predicted_variance

# Compare Predictions with True Squared Returns (r_t^2)
true_squared_returns = test_returns ** 2  # True squared returns

'''
# Plot Predicted Variance vs True Squared Returns
plt.figure(figsize=(10, 6))
plt.plot(predicted_variance, label="GARCH-t(1,1) Dynamic Predicted Variance")
plt.plot(true_squared_returns, label="True Squared Returns (r_t^2)", alpha=0.7)
plt.xlabel("Time Steps")
plt.ylabel("Variance")
plt.title("GARCH-t(1,1) Dynamic Predictions vs. True Squared Returns")
plt.legend()
plt.show()
'''
# Out:
# '\n# Plot Predicted Variance vs True Squared Returns\nplt.figure(figsize=(10, 6))\nplt.plot(predicted_variance, label="GARCH-t(1,1) Dynamic Predicted Variance")\nplt.plot(true_squared_returns, label="True Squared Returns (r_t^2)", alpha=0.7)\nplt.xlabel("Time Steps")\nplt.ylabel("Variance")\nplt.title("GARCH-t(1,1) Dynamic Predictions vs. True Squared Returns")\nplt.legend()\nplt.show()\n'

# %%
# Calculate MSE
# Step 1: Predict variance h_t
predicted_h = predicted_variance

# Step 2: Compute E(|r_t|^c | S_{t-1}) for c = 1, 1.5, 2
expectations = {c: compute_expectation(predicted_h, c, nu) for c in c_values}

# Step 3: Calculate MSE
mse_results = calculate_mse(np.sqrt(r_squared), expectations, c_values)
mae_results = calculate_mae(np.sqrt(r_squared), expectations, c_values)
name = "GARCH"
mse_results_all[name] = mse_results
mae_results_all[name] = mae_results

# %%
# Initialize with training data
rolling_train_returns = np.append(train_returns,val_returns).copy()
rolling_train_returns *= 100
predicted_variance = []

for t in range(len(test_returns)):
    # Step 1: Fit GARCH-t(1,1) model to the rolling training data
    garch_t_model = arch_model(rolling_train_returns, vol="EGARCH", p=1, q=1, dist="t")
    res = garch_t_model.fit(disp="off")
    
    # Step 2: Forecast the next variance (h_t)
    forecast = res.forecast(start=len(rolling_train_returns)-1, horizon=1, reindex=False)
    h_t = forecast.variance.values[-1, 0]  # Forecasted variance
    
    # Step 3: Append the forecasted variance
    predicted_variance.append(h_t/100**2)
    
    # Step 4: Add the current test return to the rolling training set
    rolling_train_returns = np.append(rolling_train_returns, test_returns[t]*100)

# Convert to NumPy array
predicted_variance = np.array(predicted_variance)
egarch_predicted_variance = predicted_variance

# Compare Predictions with True Squared Returns (r_t^2)
true_squared_returns = test_returns ** 2  # True squared returns

'''
# Plot Predicted Variance vs True Squared Returns
plt.figure(figsize=(10, 6))
plt.plot(predicted_variance, label="EGARCH-t(1,1) Dynamic Predicted Variance")
plt.plot(true_squared_returns, label="True Squared Returns (r_t^2)", alpha=0.7)
plt.xlabel("Time Steps")
plt.ylabel("Variance")
plt.title("EGARCH-t(1,1) Dynamic Predictions vs. True Squared Returns")
plt.legend()
plt.show()
'''

# Calculate MSE
# Step 1: Predict variance h_t
predicted_h = predicted_variance

# Step 2: Compute E(|r_t|^c | S_{t-1}) for c = 1, 1.5, 2
expectations = {c: compute_expectation(predicted_h, c, nu) for c in c_values}

# Step 3: Calculate MSE
mse_results = calculate_mse(np.sqrt(r_squared), expectations, c_values)
mae_results = calculate_mae(np.sqrt(r_squared), expectations, c_values)
name = "EGARCH"
mse_results_all[name] = mse_results
mae_results_all[name] = mae_results

# %%
# Initialize with training data
rolling_train_returns = np.append(train_returns,val_returns).copy()
rolling_train_returns *= 100
predicted_variance = []

for t in range(len(test_returns)):
    # Step 1: Fit GARCH-t(1,1) model to the rolling training data
    garch_t_model = arch_model(rolling_train_returns, vol="GARCH", p=1, o=1, q=1, dist="t")
    res = garch_t_model.fit(disp="off")
    
    # Step 2: Forecast the next variance (h_t)
    forecast = res.forecast(start=len(rolling_train_returns)-1, horizon=1, reindex=False)
    h_t = forecast.variance.values[-1, 0]  # Forecasted variance
    
    # Step 3: Append the forecasted variance
    predicted_variance.append(h_t/100**2)
    
    # Step 4: Add the current test return to the rolling training set
    rolling_train_returns = np.append(rolling_train_returns, test_returns[t]*100)

# Convert to NumPy array
predicted_variance = np.array(predicted_variance)
gjr_garch_predicted_variance = predicted_variance

# Compare Predictions with True Squared Returns (r_t^2)
true_squared_returns = test_returns ** 2  # True squared returns

'''
# Plot Predicted Variance vs True Squared Returns
plt.figure(figsize=(10, 6))
plt.plot(predicted_variance, label="GJR-GARCH-t(1,1) Dynamic Predicted Variance")
plt.plot(true_squared_returns, label="True Squared Returns (r_t^2)", alpha=0.7)
plt.xlabel("Time Steps")
plt.ylabel("Variance")
plt.title("GJR-GARCH-t(1,1) Dynamic Predictions vs. True Squared Returns")
plt.legend()
plt.show()
'''

# Calculate MSE
# Step 1: Predict variance h_t
predicted_h = predicted_variance

# Step 2: Compute E(|r_t|^c | S_{t-1}) for c = 1, 1.5, 2
expectations = {c: compute_expectation(predicted_h, c, nu) for c in c_values}

# Step 3: Calculate MSE
mse_results = calculate_mse(np.sqrt(r_squared), expectations, c_values)
mae_results = calculate_mae(np.sqrt(r_squared), expectations, c_values)
name = "GJR-GARCH"
mse_results_all[name] = mse_results
mae_results_all[name] = mae_results

# %%
rows = 1
cols = 3
fig, axes = plt.subplots(rows, cols, figsize=(15, 5 * rows))
axes = axes.flatten()  # Flatten the axes array for easy indexing

garch_vars = {"GARCH": garch_predicted_variance, "EGARCH": egarch_predicted_variance, "GJR-GARCH": gjr_garch_predicted_variance}
for idx, (name, value) in enumerate(garch_vars.items()):
    ax = axes[idx]  # Select subplot axis
    ax.plot(value, label="Predicted Variance (h_t)", alpha=0.7)
    ax.plot(r_squared, label="True Squared Returns (r_t^2)", alpha=0.7)
    ax.set_title(f"{name}")
    ax.set_xlabel("Time Steps")
    ax.set_ylabel("Variance")
    ax.legend()
    
# Adjust layout
plt.tight_layout()
plt.savefig(f"{data_name}_GARCH_variance_comparison.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
mse_df = pd.DataFrame(mse_results_all).T
mae_df = pd.DataFrame(mae_results_all).T

# %%
pd.set_option('display.float_format', '{:.10f}'.format)
mse_df
# Out:
#                                                     1.0000000000  \
# Model 1, LSTM(32) + Dense(16-8)                     0.0000822511
# Model 2, LSTM(32) + Dense(32-16-8)                  0.0000449436
# Model 3, LSTM(32) + Dense(64-32-16-8)               0.0000471176
# Model 4, LSTM(32) + Dense(64-32-16-8) + dropout0.1  0.0000385963
# Model 5, LSTM(32) + Dense(64-32-16-8) + dropout0.2  0.0000412619
# Model 6, LSTM(32) + Dense(64-32-16-8) + dropout0.3  0.0000701814
# GARCH                                               0.0000401299
# EGARCH                                              0.0000406686
# GJR-GARCH                                           0.0000372550
#
#                                                     1.5000000000  2.0000000000
# Model 1, LSTM(32) + Dense(16-8)                     0.0000027437  0.0000001049
# Model 2, LSTM(32) + Dense(32-16-8)                  0.0000013529  0.0000000447
# Model 3, LSTM(32) + Dense(64-32-16-8)               0.0000013997  0.0000000457
# Model 4, LSTM(32) + Dense(64-32-16-8) + dropout0.1  0.0000011729  0.0000000394
# Model 5, LSTM(32) + Dense(64-32-16-8) + dropout0.2  0.0000012027  0.0000000393
# Model 6, LSTM(32) + Dense(64-32-16-8) + dropout0.3  0.0000022267  0.0000000793
# GARCH                                               0.0000012222  0.0000000413
# EGARCH                                              0.0000012347  0.0000000416
# GJR-GARCH                                           0.0000011220  0.0000000375

# %%
mae_df
# Out:
#                                                     1.0000000000  \
# Model 1, LSTM(32) + Dense(16-8)                     0.0077096141
# Model 2, LSTM(32) + Dense(32-16-8)                  0.0042684684
# Model 3, LSTM(32) + Dense(64-32-16-8)               0.0043102824
# Model 4, LSTM(32) + Dense(64-32-16-8) + dropout0.1  0.0041482705
# Model 5, LSTM(32) + Dense(64-32-16-8) + dropout0.2  0.0050626862
# Model 6, LSTM(32) + Dense(64-32-16-8) + dropout0.3  0.0073280717
# GARCH                                               0.0044804708
# EGARCH                                              0.0045167663
# GJR-GARCH                                           0.0043098740
#
#                                                     1.5000000000  2.0000000000
# Model 1, LSTM(32) + Dense(16-8)                     0.0013370962  0.0002388191
# Model 2, LSTM(32) + Dense(32-16-8)                  0.0005771491  0.0000806743
# Model 3, LSTM(32) + Dense(64-32-16-8)               0.0005747671  0.0000793918
# Model 4, LSTM(32) + Dense(64-32-16-8) + dropout0.1  0.0005722745  0.0000824625
# Model 5, LSTM(32) + Dense(64-32-16-8) + dropout0.2  0.0007783153  0.0001237112
# Model 6, LSTM(32) + Dense(64-32-16-8) + dropout0.3  0.0012990921  0.0002367827
# GARCH                                               0.0006506123  0.0000980182
# EGARCH                                              0.0006565371  0.0000986183
# GJR-GARCH                                           0.0006278342  0.0000959892

# %%
print(mae_df.to_csv())
# Out:
# ,1.0,1.5,2.0
# "Model 1, LSTM(32) + Dense(16-8)",0.007709614145770144,0.0013370961972112478,0.0002388191197058458
# "Model 2, LSTM(32) + Dense(32-16-8)",0.004268468434778336,0.0005771491130076452,8.067431652302954e-05
# "Model 3, LSTM(32) + Dense(64-32-16-8)",0.004310282353737602,0.0005747670715211346,7.939180104408883e-05
# "Model 4, LSTM(32) + Dense(64-32-16-8) + dropout0.1",0.0041482704687917085,0.0005722744957467537,8.246246123408356e-05
# "Model 5, LSTM(32) + Dense(64-32-16-8) + dropout0.2",0.005062686193895597,0.0007783152704977777,0.00012371123978245822
# "Model 6, LSTM(32) + Dense(64-32-16-8) + dropout0.3",0.007328071704029257,0.0012990920743793928,0.0002367827030520405
# GARCH,0.0044804708028489985,0.0006506122580459971,9.801815564650104e-05
# EGARCH,0.0045167662974905055,0.0006565370710082941,9.861834237417081e-05
# GJR-GARCH,0.00430987403010778,0.0006278341527463589,9.598918161429395e-05

# %%
print(mse_df.to_csv())
# Out:
# ,1.0,1.5,2.0
# "Model 1, LSTM(32) + Dense(16-8)",8.225110316276607e-05,2.7436644065305513e-06,1.0491103655693782e-07
# "Model 2, LSTM(32) + Dense(32-16-8)",4.49436456603033e-05,1.3529296637433658e-06,4.473731787112727e-08
# "Model 3, LSTM(32) + Dense(64-32-16-8)",4.7117621150157185e-05,1.399662623561573e-06,4.574663027044428e-08
# "Model 4, LSTM(32) + Dense(64-32-16-8) + dropout0.1",3.8596292338484144e-05,1.172912444207821e-06,3.94130613556207e-08
# "Model 5, LSTM(32) + Dense(64-32-16-8) + dropout0.2",4.12618962047382e-05,1.2027463425246987e-06,3.932567935628471e-08
# "Model 6, LSTM(32) + Dense(64-32-16-8) + dropout0.3",7.018135026323573e-05,2.226707421767533e-06,7.934297724988287e-08
# GARCH,4.012987878395924e-05,1.2222075554292734e-06,4.13447089209597e-08
# EGARCH,4.066864093453472e-05,1.2346768138662588e-06,4.155394195092214e-08
# GJR-GARCH,3.7254965372818366e-05,1.1219708125748413e-06,3.754532534577406e-08
